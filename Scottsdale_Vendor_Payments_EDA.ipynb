# %% [markdown]
# ### City of Scottsdale Vendor Payments - EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker
import seaborn as sns
import datetime

vendor_payments = pd.read_csv("data/Scottsdale/ct_VendorPayments.csv")

vendor_payments['PaymentDate'] = pd.to_datetime(vendor_payments['PaymentDate'])
vendor_payments['Month'] = vendor_payments['PaymentDate'].dt.month
vendor_payments['Day_of_Year'] = vendor_payments['PaymentDate'].dt.dayofyear

# %%
# date range of data
print(vendor_payments['PaymentDate'].min())
print(vendor_payments['PaymentDate'].max())
# Out:
# 2017-08-14 00:00:00
# 2018-08-10 00:00:00

# %%
vendor_payments.head()
# Out:
#   PaymentDate                                     VendorName  PaymentAmount  \
# 0  2017-08-14  A TO Z EQUIPMENT RENTAL & SALES                      1021.38
# 1  2017-08-14  AIMS PVIC                                             380.00
# 2  2017-08-14  AIMS PVIC                                            2125.00
# 3  2017-08-14  AIMS PVIC                                           15658.03
# 4  2017-08-14  ALL CITY TOWING                                       583.00
#
#    Fund    FundDescription Center                           CenterName  \
# 0   200     TRANSPORTATION  20860  TRAFFIC SIGNALS
# 1   100            GENERAL  25411  IRRIGATION REPAIR
# 2   200     TRANSPORTATION  20810  GRADING AND DRAINAGE
# 3   603  WATER RECLAMATION  29321  SEWER SYSTEM
# 4   700   FLEET MANAGEMENT  20706  FLEET MANAGEMENT OPERATIONS
#
#    Account                          AccountName  FiscalYear  AccountingPeriod  \
# 0    53790  MAT TO MAINT & REPAIR MACH, EQUIP          2018                 2
# 1    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
# 2    52390  MISC MAINTENANCE AND REPAIR                2018                 2
# 3    52190  OTHER PROFESSIONAL SERVICES                2018                 2
# 4    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
#
#    Month  Day_of_Year
# 0      8          226
# 1      8          226
# 2      8          226
# 3      8          226
# 4      8          226

# %%
vendor_payments.dtypes
# Out:
# PaymentDate         datetime64[ns]
# VendorName                  object
# PaymentAmount              float64
# Fund                         int64
# FundDescription             object
# Center                      object
# CenterName                  object
# Account                      int64
# AccountName                 object
# FiscalYear                   int64
# AccountingPeriod             int64
# Month                        int64
# Day_of_Year                  int64
# dtype: object

# %%
vendor_payments.sort_values(by='PaymentAmount', ascending=False).reset_index().head()
# Out:
#    index PaymentDate                                     VendorName  \
# 0  20725  2018-06-28  JE DUNN CONSTRUCTION COMPANY
# 1  17835  2018-05-17  JE DUNN CONSTRUCTION COMPANY
# 2  10912  2018-01-31  CIGNA HEALTHCARE
# 3   1139  2017-08-30  CIGNA HEALTHCARE
# 4   6506  2017-11-20  CENTRAL ARIZONA PROJECT
#
#    PaymentAmount  Fund          FundDescription Center  \
# 0     2716141.00   642              CIP AIRPORT  AB59A
# 1     2626524.00   642              CIP AIRPORT  AB59A
# 2     2368830.06   715  BENEFITS SELF INSURANCE  27437
# 3     2368262.77   715  BENEFITS SELF INSURANCE  27437
# 4     2292262.67   600                    WATER  29221
#
#                             CenterName  Account  \
# 0  AIRPORT TERMINAL AREA RDVLOPMENT PR    56082
# 1  AIRPORT TERMINAL AREA RDVLOPMENT PR    56082
# 2  CIGNA OAP IN-NETWORK                   52411
# 3  CIGNA OAP IN-NETWORK                   52411
# 4  CAP TREATMENT PLANT                    53070
#
#                            AccountName  FiscalYear  AccountingPeriod  Month  \
# 0  CONT - BUILDINGS                           2018                12      6
# 1  CONT - BUILDINGS                           2018                11      5
# 2  MEDICAL CLAIMS                             2018                 7      1
# 3  MEDICAL CLAIMS                             2018                 2      8
# 4  PURCHASED WATER                            2018                 5     11
#
#    Day_of_Year
# 0          179
# 1          137
# 2           31
# 3          242
# 4          324

# %%
sns.set(rc={'figure.figsize':(15,5)})

ax = sns.lineplot(x=vendor_payments.index, \
                  y="PaymentAmount", \
                  data=vendor_payments.sort_values(by='PaymentAmount', ascending=True).reset_index())

plt.title("Payment Size Distribution",fontsize=20)
plt.xlabel("Payment Count",fontsize=14)
plt.ylabel("Payments in Thousands($)",fontsize=14)
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000), ',')))
ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(1500))

# %% [markdown]
# ## Fund Analysis

# %%
fund_payments = vendor_payments \
    .groupby(['FundDescription'])['PaymentAmount'] \
    .sum() \
    .sort_values(ascending=False).head(15) \
    .apply(lambda x: int(x)) \
    .head(15)

# I would like to be able to format with $ sign and commas, however this converts it to
# a data type that can't be aggregated in the bar chart below.
# is there a way to get around this?
#     .apply(lambda x: "${:,.0f}".format(x))

fund_payments
# Out:
# FundDescription
# GENERAL                              44507852
# WATER                                33524119
# BENEFITS SELF INSURANCE              31977066
# CIP AIRPORT                          18602434
# CIP WATER                            15878392
# TRANSPORTATION                       14885857
# TOURISM DEVELOPMENT                  14175547
# CIP WATER RECLAMATION                13231773
# CIP TRANSPORTATION PRIVILEGE TAX     12622688
# CIP GENERAL                          11481031
# WATER RECLAMATION                    10422529
# FLEET MANAGEMENT                      9112504
# CIP FEDERAL GRANTS                    8931516
# 2017A MPC BONDS-WATER                 7339598
# SOLID WASTE MANAGEMENT                4509578
# Name: PaymentAmount, dtype: int64

# %%
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot(fund_payments.values, fund_payments.index, palette='Blues_d')
plt.title('Payments by Fund',fontsize=20)
plt.tick_params(labelsize=12)

plt.ylabel('Fund',fontsize=15)
plt.xlabel('Payments in Millions',fontsize=15)

ax.get_xaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000000), ',')))

# %%
fund_payments_mean = vendor_payments \
    .groupby(['FundDescription'])['PaymentAmount'] \
    .mean() \
    .sort_values(ascending=False) \
    .apply(lambda x: int(x)) \
    .head(15)


fund_payments_mean
# Out:
# FundDescription
# CIP AIRPORT                            229659
# HOME                                   184819
# 2017A MPC BONDS-WATER                  156161
# 2017B MPC BONDS AVIATION               152690
# 2017A MPC BONDS-WATER DF               135006
# CIP FEDERAL GRANTS                     129442
# WATER DEVELOPMENT                      128109
# BENEFITS SELF INSURANCE                125893
# 2015 GO BOND Q4-STREET PAVEMT REHAB    111624
# CIP RWDS                                99474
# CIP FLOOD CNTRL DISTRCT CONTRIB/IGA     93698
# CIP STADIUM IMPROVEMENT IGA             68916
# 2015 GO BONDS Q5-PUBLIC SAFETY-FIRE     60332
# CIP SRP MARICOPA INDIAN COM CONTRIB     58453
# TOURISM DEVELOPMENT                     56476
# Name: PaymentAmount, dtype: int64

# %%
fund_payments_mean.dtypes
# Out:
# dtype('int64')

# %%
sns.set(rc={'figure.figsize':(15,5)})

ax = sns.barplot(fund_payments_mean.values, fund_payments_mean.index, palette='Blues_d')
plt.title('Mean Payments by Fund',fontsize=20)
plt.tick_params(labelsize=12)

plt.ylabel('Fund',fontsize=15)
plt.xlabel('Payments in Thousands',fontsize=15)

ax.get_xaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000), ',')))

# %% [markdown]
# ## Cost Center Analysis

# %%
center_payments = vendor_payments \
    .groupby(['CenterName'])['PaymentAmount'] \
    .sum() \
    .sort_values(ascending=False) \
    .apply(lambda x: int(x)) \
    .head(15)

center_payments
# Out:
# CenterName
# CIGNA OAP IN-NETWORK                   23013387
# CAP TREATMENT PLANT                    18780287
# AIRPORT TERMINAL AREA RDVLOPMENT PR    18515382
# DESTINATION MARKETING CONTRACT          9879556
# VEHICLE ACQUISITIONS                    7181229
# BOOSTER STATIONS                        5855296
# FLW 24 TRANS MAIN & BOOSTER MOD         4743386
# CIGNA OAP                               4690873
# PAVEMENT OVERLAY PROGRAM                4608992
# CULTURAL COUNCIL CONTRACT               4576580
# ASPHALT & MAINTENANCE                   4560945
# WASTEWATER COLLECTION SYSTEM IMPROV     4464733
# WATER TREATMENT FACILITY IMPR           4321891
# DATA CENTER RESILIENCY PLAN             4052343
# UTILITIES                               3909870
# Name: PaymentAmount, dtype: int64

# %%
sns.set(rc={'figure.figsize':(15,5)})

ax = sns.barplot(center_payments.values, center_payments.index, palette='Blues_d')
plt.title('Payments by Cost Center',fontsize=20)
plt.tick_params(labelsize=12)

plt.ylabel('Center',fontsize=15)
plt.xlabel('Payments',fontsize=15)
ax.get_xaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000000), ',')))

plt.tick_params(labelsize=12)

# %%
center_payments_mean = vendor_payments \
    .groupby(['CenterName'])['PaymentAmount'] \
    .mean() \
    .sort_values(ascending=False) \
    .apply(lambda x: int(x)) \
    .head(15)
    
center_payments_mean
# Out:
# CenterName
# APS RAINTREE ID I-6002                 1021050
# POLICE PORT & VHCL RADIO REP            991027
# TRANSIT BUS PURCHASES-X109              847146
# DESTINATION MARKETING CONTRACT          759965
# CULTURAL COUNCIL CONTRACT               508508
# CIGNA OAP IN-NETWORK                    479445
# TRANSIT BUS PURCHASES                   321205
# SROG WW TREATMENT PLANT IMP             305398
# AIRPORT TERMINAL AREA RDVLOPMENT PR     280536
# WATER TREATMENT PLANT MEMBRANES         258517
# SWG FRNCHSE CAPTL RECOVERY FEE          250740
# FLW 24 TRANS MAIN & BOOSTER MOD         215608
# SROG TRANSMISSION LINE                  198718
# DOWNTOWN MARSHALL WAY L & EO *10/17     190502
# RECONSTRUCT TAXIWAY A AND EXITS         189640
# Name: PaymentAmount, dtype: int64

# %%
sns.set(rc={'figure.figsize':(15,5)})

ax = sns.barplot(center_payments_mean.values, center_payments_mean.index, palette='Blues_d')
plt.title('Mean Payments by Cost Center',fontsize=20)
plt.tick_params(labelsize=12)

plt.ylabel('Center',fontsize=15)
plt.xlabel('Payments',fontsize=15)
ax.get_xaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000000), ',')))

plt.tick_params(labelsize=12)

# sns.dark_palette("muted purple", input="xkcd")


# sns.color_palette(palette='pastel', n_colors=None, desat=None)
# Return a list of colors defining a color palette.

# Available seaborn palette names:
# deep, muted, bright, pastel, dark, colorblind

# %% [markdown]
# ## Account Analysis

# %%
account_payments = vendor_payments \
    .groupby(['AccountName'])['PaymentAmount'] \
    .sum() \
    .sort_values(ascending=False) \
    .apply(lambda x: int(x)) \
    .reset_index() \
    .head(15)

account_payments.iloc[:,0]
# Out:
# 0     MEDICAL CLAIMS
# 1     ELECTRIC
# 2     CONT - BUILDINGS
# 3     PURCHASED WATER
# 4     CONT - STREETS
# 5     CONT - WATER - DISTRIBUTION SYSTEM
# 6     CONT - OTHER
# 7     DESTINATION MARKETING CONTRACT
# 8     MOTOR VEHICLES
# 9     OTHER PROFESSIONAL SERVICES
# 10    CONT - WATER - BOOSTER STATION
# 11    CULTURAL COUNCIL CONTRACT
# 12    EQUP - MOTOR VEHICLES
# 13    SOFTWARE MAINT & LICENSING
# 14    MAINT - MACHINERY, EQUIP & AUTOS
# Name: AccountName, dtype: object

# %%
sns.set(rc={'figure.figsize':(15,5)})

ax = sns.barplot(account_payments.iloc[:,1], account_payments.iloc[:,0], palette="Blues_d")
plt.title('Payments by Account',fontsize=20)
plt.tick_params(labelsize=12)

plt.ylabel('Account',fontsize=15)
plt.xlabel('Payments in Millions',fontsize=15)
ax.get_xaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000000), ',')))

# %%
account_payments_mean = vendor_payments \
    .groupby(['AccountName'])['PaymentAmount'] \
    .mean() \
    .sort_values(ascending=False) \
    .apply(lambda x: int(x)) \
    .head(15)

account_payments_mean
# Out:
# AccountName
# EQUP - RADIOS                          991027
# BLDG - BLDG/PURCH BGT USE ONLY         971355
# DESTINATION MARKETING CONTRACT         759965
# CULTURAL COUNCIL CONTRACT              508508
# EQUP - MOTOR VEHICLES                  508381
# MEDICAL CLAIMS                         350733
# PURCHASED WATER                        316098
# PURCHASING CARD EXPENSE                291392
# FIRE SERVICE CONTRACTS                 249768
# TREATMENT FILTER MEDIA                 215948
# STREET OVERLAY                         191373
# CONT - BUILDINGS                       175339
# PHOENIX TRANSIT CONTRACTS              172550
# CONT - WATER - DISTRIBUTION SYSTEM     136602
# IT - LICENSES & OTHER FEES             135999
# Name: PaymentAmount, dtype: int64

# %%
sns.set(rc={'figure.figsize':(15,5)})

ax = sns.barplot(account_payments_mean.values, account_payments_mean.index, palette='Blues_d')
plt.title('Mean Payments by Account',fontsize=20)
plt.tick_params(labelsize=12)

plt.ylabel('Account',fontsize=15)
plt.xlabel('Payments in Thousands',fontsize=15)
ax.get_xaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000), ',')))

# %% [markdown]
# # Vendor Name Analysis
#
# ### Which Vendors are being paid the most?  And at what times of the year?

# %%
vendor_analysis = vendor_payments \
    .groupby(['VendorName'])['PaymentAmount'] \
    .sum() \
    .sort_values(ascending=False) \
    .apply(lambda x: int(x)) \
    .reset_index()
    
vendor_analysis.head(10)
# Out:
#                                       VendorName  PaymentAmount
# 0  CIGNA HEALTHCARE                                    31176352
# 1  APS                                                 19863683
# 2  JE DUNN CONSTRUCTION COMPANY                        17107677
# 3  CENTRAL ARIZONA PROJECT                             14645247
# 4  MGC CONTRACTORS INC                                 13886155
# 5  SCOTTSDALE CONVENTION & VISITORS BUREAU             10044495
# 6  CITY OF PHOENIX                                      8428397
# 7  HUNTER CONTRACTING CO                                6461100
# 8  M R TANNER CONSTRUCTION                              6063651
# 9  SCOTTSDALE CULTURAL COUNCIL                          5864866

# %%
# ax = sns.set(rc={'figure.figsize':(15,10)})

fig = plt.figure(figsize=(15, 10))


ax = sns.barplot(vendor_analysis.iloc[:,1].head(50),vendor_analysis.iloc[:,0].head(30), palette="Blues_d")
# plt.title('Payments by Vendor')
# plt.tick_params(labelsize=12)

plt.ylabel('Vendor')
plt.xlabel('Payments in Millions')

sns.set_context("notebook", font_scale=2.5)

ax.get_xaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000000), ',')))

plt.savefig('visualizations/Payments by Vendor - top 30.png', bbox_inches='tight')

# %%
# account_payments['AccountName'].to_frame().head()
vendor_analysis.iloc[:,0].to_frame().head()
# Out:
#                                       VendorName
# 0  CIGNA HEALTHCARE
# 1  APS
# 2  JE DUNN CONSTRUCTION COMPANY
# 3  CENTRAL ARIZONA PROJECT
# 4  MGC CONTRACTORS INC

# %%
top_vendors = pd.merge(vendor_analysis.iloc[:,0].to_frame().head(), vendor_payments, on=['VendorName'])
top_vendors.head()
# Out:
#                                       VendorName PaymentDate  PaymentAmount  \
# 0  CIGNA HEALTHCARE                               2017-08-30     2368262.77
# 1  CIGNA HEALTHCARE                               2017-08-30      467957.07
# 2  CIGNA HEALTHCARE                               2017-08-30       75908.96
# 3  CIGNA HEALTHCARE                               2017-08-30      145056.15
# 4  CIGNA HEALTHCARE                               2017-08-30      106161.01
#
#    Fund          FundDescription Center                           CenterName  \
# 0   715  BENEFITS SELF INSURANCE  27437  CIGNA OAP IN-NETWORK
# 1   715  BENEFITS SELF INSURANCE  27438  CIGNA OAP
# 2   715  BENEFITS SELF INSURANCE  27439  CIGNA OAP HSA
# 3   715  BENEFITS SELF INSURANCE  27453  CIGNA PPO DENTAL
# 4   715  BENEFITS SELF INSURANCE  27454  CIGNA LOC PLUS IN-NETWRK
#
#    Account                          AccountName  FiscalYear  AccountingPeriod  \
# 0    52411  MEDICAL CLAIMS                             2018                 2
# 1    52411  MEDICAL CLAIMS                             2018                 2
# 2    52411  MEDICAL CLAIMS                             2018                 2
# 3    52410  DENTAL CLAIMS                              2018                 2
# 4    52411  MEDICAL CLAIMS                             2018                 2
#
#    Month  Day_of_Year
# 0      8          242
# 1      8          242
# 2      8          242
# 3      8          242
# 4      8          242

# %%
top_vendors_monthly = top_vendors \
    .groupby(['Month','VendorName'])['PaymentAmount'] \
    .sum() \
    .sort_values(ascending=False) \
    .apply(lambda x: int(x)) \
    .reset_index()

top_vendors_monthly.shape
# Out:
# (59, 3)

# %%
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.lineplot(x="Month", \
                  y="PaymentAmount", \
                  hue="VendorName", \
                  data=top_vendors_monthly)

# plt.title("Vendor Payments by Month of Year")
plt.xlabel("Month of Year", fontsize=15)
plt.ylabel("Payments in Thousands", fontsize=15)
# plt.tick_params(labelsize=12)
plt.legend(fontsize=8)


# sns.set_context("notebook", font_scale=5)

ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000), ',')))

ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator())

# %% [markdown]
# ### Which funds are these highest paid vendors being paid from?  And how do the sizes of payments change throughout the year?

# %%
fig = plt.figure(figsize=(15, 10))
ax = sns.scatterplot(x=top_vendors.loc[:,'Day_of_Year'], 
                y=top_vendors.loc[:,'Fund'],
                hue=top_vendors.loc[:,'VendorName'],
                s=top_vendors.loc[:,'PaymentAmount']/100,
                alpha=0.5)

# plt.title("xxx")
plt.xlabel("Day of the Year", fontsize=15)
plt.ylabel("Fund", fontsize=15)
# plt.legend(fontsize=15)
plt.ylim(0,1100)

# sns.set_context("notebook", font_scale=1)

ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(25))
ax.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(50))
plt.savefig("visualizations/top 5 vendors - fund,day of year, calibrated by size of pmt.png")

# %% [markdown]
# #### Overall, I would say the scatterplot graph in this scenario is a bit messy.  However, it's interesting to see that APS is the only vendor in the group being paid from two different funds.  All the others are being paid from a single fund.

# %% [markdown]
# # Payment Frequency Throughout The Year

# %%
account_payments_day_of_year = vendor_payments \
    .groupby(['Day_of_Year'])['PaymentAmount'] \
    .sum() \
    .reset_index() 
   
account_payments_day_of_year.head()
# Out:
#    Day_of_Year  PaymentAmount
# 0            2     1101509.03
# 1            3      129001.55
# 2            4      383677.96
# 3            5      498351.85
# 4            8     1191590.60

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.lineplot(x="Day_of_Year", \
             y="PaymentAmount", \
             data=account_payments_day_of_year,\
             color='r')

plt.title("Payments by Day of Year",fontsize=20)
plt.xlabel("Day of Year",fontsize=14)
# plt.ylim(0, 40000000)

plt.ylabel("Payments in Millions",fontsize=14)
plt.tick_params(labelsize=12)

handles, labels = ax.get_legend_handles_labels()
ax.legend(labels=labels[1:])

ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000000), ',')))

ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(25))

# %%
# how do payments for only the top 5 accounts by spending track accross the year?
# I need to find only data for the top 5 accounts by spending

# selecting only AccountName produces a series, which I can't use to merge
# the to_frame function allows me to convert the series to a dataframe, which I can use to do my merge
account_payments['AccountName'].to_frame().head()
# Out:
#                            AccountName
# 0  MEDICAL CLAIMS
# 1  ELECTRIC
# 2  CONT - BUILDINGS
# 3  PURCHASED WATER
# 4  CONT - STREETS

# %%
#subselect only data for the top 5 accounts by spending
top_5_accts = pd.merge(account_payments['AccountName'].to_frame().head(), vendor_payments, on=['AccountName'])
top_5_accts.head()
# Out:
#                            AccountName PaymentDate  \
# 0  MEDICAL CLAIMS                       2017-08-30
# 1  MEDICAL CLAIMS                       2017-08-30
# 2  MEDICAL CLAIMS                       2017-08-30
# 3  MEDICAL CLAIMS                       2017-08-30
# 4  MEDICAL CLAIMS                       2017-08-30
#
#                                       VendorName  PaymentAmount  Fund  \
# 0  CIGNA HEALTHCARE                                  2368262.77   715
# 1  CIGNA HEALTHCARE                                   467957.07   715
# 2  CIGNA HEALTHCARE                                    75908.96   715
# 3  CIGNA HEALTHCARE                                   106161.01   715
# 4  CIGNA HEALTHCARE                                     9481.05   717
#
#                        FundDescription Center  \
# 0              BENEFITS SELF INSURANCE  27437
# 1              BENEFITS SELF INSURANCE  27438
# 2              BENEFITS SELF INSURANCE  27439
# 3              BENEFITS SELF INSURANCE  27454
# 4  BENEFITS SELF INS DIS PSPRS RETIREE  27450
#
#                             CenterName  Account  FiscalYear  AccountingPeriod  \
# 0  CIGNA OAP IN-NETWORK                   52411        2018                 2
# 1  CIGNA OAP                              52411        2018                 2
# 2  CIGNA OAP HSA                          52411        2018                 2
# 3  CIGNA LOC PLUS IN-NETWRK               52411        2018                 2
# 4  CIGNA OAP IN-NETWORK PSPRS RETIREES    52411        2018                 2
#
#    Month  Day_of_Year
# 0      8          242
# 1      8          242
# 2      8          242
# 3      8          242
# 4      8          242

# %%
top_5_accts_monthly = top_5_accts \
    .groupby(['Month','AccountName'])['PaymentAmount'] \
    .sum() \
    .sort_values(ascending=False) \
    .apply(lambda x: int(x)) \
    .reset_index()

top_5_accts_monthly.head()
# Out:
#    Month                          AccountName  PaymentAmount
# 0      9  CONT - STREETS                             3510431
# 1      5  CONT - BUILDINGS                           3383151
# 2      6  CONT - BUILDINGS                           3381570
# 3      1  MEDICAL CLAIMS                             3237521
# 4     12  CONT - STREETS                             3169840

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax = sns.lineplot(x="Month", \
                  y="PaymentAmount", \
                  hue="AccountName", \
                  data=top_5_accts_monthly)

# plt.title("Account Payments by Month of Year",fontsize=20)
plt.xlabel("Month of Year",fontsize=14)
plt.ylabel("Payments in Thousands",fontsize=14)
plt.tick_params(labelsize=12)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:], loc='upper center', bbox_to_anchor=(0.5, -0.15),ncol=5,fontsize=10,frameon=False)

ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000), ',')))

ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator())

# %%
top_5_accts_day_of_year = top_5_accts \
    .groupby(['Day_of_Year','AccountName'])['PaymentAmount'] \
    .sum() \
    .sort_values(ascending=False) \
    .apply(lambda x: int(x)) \
    .reset_index()

top_5_accts_day_of_year.head()
# Out:
#    Day_of_Year                          AccountName  PaymentAmount
# 0           31  MEDICAL CLAIMS                             3237521
# 1          242  MEDICAL CLAIMS                             3056916
# 2          212  MEDICAL CLAIMS                             2932787
# 3          179  CONT - BUILDINGS                           2716141
# 4          151  MEDICAL CLAIMS                             2641072

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax = sns.lineplot(x="Day_of_Year", \
                  y="PaymentAmount", \
                  hue="AccountName", \
                  data=top_5_accts_day_of_year)

# plt.title("Top 5 Accounts - Payments by Day of Year",fontsize=20)
plt.xlabel("Day of Year",fontsize=14)
plt.ylabel("Payments in Thousands",fontsize=14)
plt.tick_params(labelsize=12)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:], loc='upper center', bbox_to_anchor=(0.5, -0.15),ncol=5,fontsize=10,frameon=False)

ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/1000), ',')))

ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(25))
plt.savefig('visualizations/Top 5 Accounts - Payments by Day of Year.png',bbox_inches='tight')

# %% [markdown]
# #### How are vendor payments structured throughout the year, based on size of payment and fund?

# %%
vendor_payments.head()
# Out:
#   PaymentDate                                     VendorName  PaymentAmount  \
# 0  2017-08-14  A TO Z EQUIPMENT RENTAL & SALES                      1021.38
# 1  2017-08-14  AIMS PVIC                                             380.00
# 2  2017-08-14  AIMS PVIC                                            2125.00
# 3  2017-08-14  AIMS PVIC                                           15658.03
# 4  2017-08-14  ALL CITY TOWING                                       583.00
#
#    Fund    FundDescription Center                           CenterName  \
# 0   200     TRANSPORTATION  20860  TRAFFIC SIGNALS
# 1   100            GENERAL  25411  IRRIGATION REPAIR
# 2   200     TRANSPORTATION  20810  GRADING AND DRAINAGE
# 3   603  WATER RECLAMATION  29321  SEWER SYSTEM
# 4   700   FLEET MANAGEMENT  20706  FLEET MANAGEMENT OPERATIONS
#
#    Account                          AccountName  FiscalYear  AccountingPeriod  \
# 0    53790  MAT TO MAINT & REPAIR MACH, EQUIP          2018                 2
# 1    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
# 2    52390  MISC MAINTENANCE AND REPAIR                2018                 2
# 3    52190  OTHER PROFESSIONAL SERVICES                2018                 2
# 4    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
#
#    Month  Day_of_Year
# 0      8          226
# 1      8          226
# 2      8          226
# 3      8          226
# 4      8          226
