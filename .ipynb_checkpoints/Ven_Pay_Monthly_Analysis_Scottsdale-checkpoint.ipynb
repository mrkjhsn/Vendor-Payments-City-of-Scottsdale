# %% [markdown]
# ### Opportunity to explore vendor payments(City of Scottsdale) and experiment with pandas styling features.  Following along from example by [Chris Moffitt](https://pbpython.com/styling-pandas.html)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker
import seaborn as sns
import datetime

vendor_payments = pd.read_csv("data/Scottsdale/ct_VendorPayments.csv")

vendor_payments['PaymentDate'] = pd.to_datetime(vendor_payments['PaymentDate'])
vendor_payments['Month'] = vendor_payments['PaymentDate'].dt.month
vendor_payments['Day_of_Year'] = vendor_payments['PaymentDate'].dt.dayofyear

# %%
# date range of data
print(vendor_payments['PaymentDate'].min())
print(vendor_payments['PaymentDate'].max())
# Out:
# 2017-08-14 00:00:00
# 2018-08-10 00:00:00

# %%
vendor_payments.head()
# Out:
#   PaymentDate                                     VendorName  PaymentAmount  \
# 0  2017-08-14  A TO Z EQUIPMENT RENTAL & SALES                      1021.38
# 1  2017-08-14  AIMS PVIC                                             380.00
# 2  2017-08-14  AIMS PVIC                                            2125.00
# 3  2017-08-14  AIMS PVIC                                           15658.03
# 4  2017-08-14  ALL CITY TOWING                                       583.00
#
#    Fund    FundDescription Center                           CenterName  \
# 0   200     TRANSPORTATION  20860  TRAFFIC SIGNALS
# 1   100            GENERAL  25411  IRRIGATION REPAIR
# 2   200     TRANSPORTATION  20810  GRADING AND DRAINAGE
# 3   603  WATER RECLAMATION  29321  SEWER SYSTEM
# 4   700   FLEET MANAGEMENT  20706  FLEET MANAGEMENT OPERATIONS
#
#    Account                          AccountName  FiscalYear  AccountingPeriod  \
# 0    53790  MAT TO MAINT & REPAIR MACH, EQUIP          2018                 2
# 1    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
# 2    52390  MISC MAINTENANCE AND REPAIR                2018                 2
# 3    52190  OTHER PROFESSIONAL SERVICES                2018                 2
# 4    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
#
#    Month  Day_of_Year
# 0      8          226
# 1      8          226
# 2      8          226
# 3      8          226
# 4      8          226

# %%
# group by month and subtotal data for each month
monthly_payments = vendor_payments.groupby([pd.Grouper(key='PaymentDate', freq='M')]) \
    ['PaymentAmount'].agg('sum') \
    .reset_index()

# compute percent of total for each month
monthly_payments['percent_total'] = monthly_payments['PaymentAmount'] / monthly_payments['PaymentAmount'].sum()

# format data to be more readable
monthly_payments = monthly_payments.style.format({'PaymentAmount': '${0:,.0f}', 'percent_total': '{:.2%}'}).hide_index()
monthly_payments
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >PaymentDate</th>
#         <th class="col_heading level0 col1" >PaymentAmount</th>
#         <th class="col_heading level0 col2" >percent_total</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row0_col0" class="data row0 col0" >2017-08-31 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row0_col1" class="data row0 col1" >$16,407,638</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row0_col2" class="data row0 col2" >5.65%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row1_col0" class="data row1 col0" >2017-09-30 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row1_col1" class="data row1 col1" >$18,977,599</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row1_col2" class="data row1 col2" >6.53%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row2_col0" class="data row2 col0" >2017-10-31 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row2_col1" class="data row2 col1" >$27,377,901</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row2_col2" class="data row2 col2" >9.42%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row3_col0" class="data row3 col0" >2017-11-30 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row3_col1" class="data row3 col1" >$21,451,298</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row3_col2" class="data row3 col2" >7.38%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row4_col0" class="data row4 col0" >2017-12-31 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row4_col1" class="data row4 col1" >$25,749,321</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row4_col2" class="data row4 col2" >8.86%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row5_col0" class="data row5 col0" >2018-01-31 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row5_col1" class="data row5 col1" >$24,807,941</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row5_col2" class="data row5 col2" >8.54%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row6_col0" class="data row6 col0" >2018-02-28 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row6_col1" class="data row6 col1" >$22,644,036</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row6_col2" class="data row6 col2" >7.79%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row7_col0" class="data row7 col0" >2018-03-31 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row7_col1" class="data row7 col1" >$21,600,046</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row7_col2" class="data row7 col2" >7.43%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row8_col0" class="data row8 col0" >2018-04-30 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row8_col1" class="data row8 col1" >$24,666,970</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row8_col2" class="data row8 col2" >8.49%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row9_col0" class="data row9 col0" >2018-05-31 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row9_col1" class="data row9 col1" >$26,209,036</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row9_col2" class="data row9 col2" >9.02%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row10_col0" class="data row10 col0" >2018-06-30 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row10_col1" class="data row10 col1" >$26,232,086</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row10_col2" class="data row10 col2" >9.03%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row11_col0" class="data row11 col0" >2018-07-31 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row11_col1" class="data row11 col1" >$28,584,890</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row11_col2" class="data row11 col2" >9.83%</td>
#     </tr>    <tr>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row12_col0" class="data row12 col0" >2018-08-31 00:00:00</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row12_col1" class="data row12 col1" >$5,948,562</td>
#         <td id="T_1c76c52e_9216_11e9_8a50_9cb6d0ea6ad2row12_col2" class="data row12 col2" >2.05%</td>
#     </tr></tbody>
# </table>

# %%
monthly_sales \
    .bar(color='orange',subset=['PaymentAmount'], align='zero') \
    .bar(color='lightblue', subset=['percent_total'], align='zero') \
    .set_caption('Monthly Vendor Payments')
# Out:
# <style  type="text/css" >
#     #T_af608ff6_921b_11e9_8bcf_9cb6d0ea6ad2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightred 50%, lightred 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightred 50%, lightred 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightgreen 50%, lightgreen 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightred 50%, lightred 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightgreen 50%, lightgreen 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightorange 50%, lightorange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightred 50%, lightred 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightgreen 50%, lightgreen 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightorange 50%, lightorange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightred 50%, lightred 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightgreen 50%, lightgreen 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightorange 50%, lightorange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightred 50%, lightred 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightgreen 50%, lightgreen 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightorange 50%, lightorange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#         }    #T_af608ff6_921b_11e9_8bcf_9cb6d0ea6ad2row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-grad

# %% [markdown]
# #### This is an easy way to glance at the data and get a sense for quantities.  However, I find myself usually sorting to get the largest/smallest values at the top.

# %%
# group by month and subtotal data for each month
fund_payments = vendor_payments.groupby('Fund') \
    ['PaymentAmount'].sum() \
    .reset_index()

# compute percent of total for each fund
fund_payments['percent_total'] = fund_payments['PaymentAmount'] / fund_payments['PaymentAmount'].sum()

# format data to be more readable
fund_payments = fund_payments \
    .style.format({'PaymentAmount': '${0:,.0f}', 'percent_total': '{:.2%}'}) \
    .hide_index() \
    .bar(color='skyblue', subset=['PaymentAmount'])

fund_payments
# Out:
# <style  type="text/css" >
#     #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 100.0%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 33.4%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 1.6%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.8%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.4%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 4.5%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.0%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 7.4%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 31.8%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.3%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 25.8%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 1.1%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 28.4%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.0%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 3.4%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 2.1%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 1.7%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row19_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.0%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.5%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.0%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.1%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 20.1%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.6%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 3.6%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 8.5%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 10.0%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 4.8%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 75.3%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row33_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.4%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row34_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 35.7%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row35_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 23.4%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row36_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 3.9%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row37_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 29.7%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row38_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row39_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 1.9%, transparent 0%);
#         }    #T_d0a6e9ee_921b_11e9_93fd_9cb6d0ea6ad2row40_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_d0a6e9e

# %%
vendor_payments.head()
# Out:
#   PaymentDate                                     VendorName  PaymentAmount  \
# 0  2017-08-14  A TO Z EQUIPMENT RENTAL & SALES                      1021.38
# 1  2017-08-14  AIMS PVIC                                             380.00
# 2  2017-08-14  AIMS PVIC                                            2125.00
# 3  2017-08-14  AIMS PVIC                                           15658.03
# 4  2017-08-14  ALL CITY TOWING                                       583.00
#
#    Fund    FundDescription Center                           CenterName  \
# 0   200     TRANSPORTATION  20860  TRAFFIC SIGNALS
# 1   100            GENERAL  25411  IRRIGATION REPAIR
# 2   200     TRANSPORTATION  20810  GRADING AND DRAINAGE
# 3   603  WATER RECLAMATION  29321  SEWER SYSTEM
# 4   700   FLEET MANAGEMENT  20706  FLEET MANAGEMENT OPERATIONS
#
#    Account                          AccountName  FiscalYear  AccountingPeriod  \
# 0    53790  MAT TO MAINT & REPAIR MACH, EQUIP          2018                 2
# 1    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
# 2    52390  MISC MAINTENANCE AND REPAIR                2018                 2
# 3    52190  OTHER PROFESSIONAL SERVICES                2018                 2
# 4    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
#
#    Month  Day_of_Year
# 0      8          226
# 1      8          226
# 2      8          226
# 3      8          226
# 4      8          226

# %% [markdown]
# ### For each vendor, what funds are they being paid from? and in which months are they receiving those payments?

# %%
pd.pivot_table(vendor_payments, index=['VendorName', 'Fund'], columns=['Month'], aggfunc=[np.sum], values=['PaymentAmount']).reset_index()
# Out:
#                                           VendorName Fund           sum  \
#                                                           PaymentAmount
# Month                                                                 1
# 0      1 800 RADIATOR                                 700           NaN
# 1      1800 RADIATOR                                  700           NaN
# 2      232 RANCH LLC                                  100           NaN
# 3      3M                                             200       2444.75
# 4      4IMPRINT INC                                   100           NaN
# 5      4IMPRINT INC                                   230       1488.79
# 6      4IMPRINT INC                                   280           NaN
# 7      4M CONSULTING GROUP LLC                        200           NaN
# 8      A & M GRAPHICS                                 100           NaN
# 9      A COMPANY INC PORTABLE RESTROOMS               100           NaN
# 10     A COMPANY INC PORTABLE RESTROOMS               650           NaN
# 11     A FOREIGN LANGUAGE SERVICE CORP                100           NaN
# 12     A MIND FOR DETAIL INC                          100       1450.62
# 13     A MIND FOR DETAIL INC                          200           NaN
# 14     A NEW LEAF                                     230       9590.25
# 15     A RAZORS EDGE                                  100       1250.00
# 16     A RAZORS EDGE                                  200           NaN
# 17     A RAZORS EDGE                                  700        175.00
# 18     A TO Z EQUIPMENT RENTAL & SALES                100       3228.12
# 19     A TO Z EQUIPMENT RENTAL & SALES                200           NaN
# 20     A TO Z EQUIPMENT RENTAL & SALES                230           NaN
# 21     A TO Z EQUIPMENT RENTAL & SALES                600        392.88
# 22     A TO Z EQUIPMENT RENTAL & SALES                603           NaN
# 23     A TO Z EQUIPMENT RENTAL & SALES                700           NaN
# 24     AAA FULL TRANSPORTATION                        200       2842.97
# 25     AARON BROWN                                    100           NaN
# 26     AARON RUTHERFORD                               100           NaN
# 27     ABACUS DIAGNOSTICS INC                         100        286.22
# 28     ABI ATTACHMENTS INC                            100           NaN
# 29     ABRAKADOODLE                                   100           NaN
# ...                                              ...  ...           ...
# 3462   WORLD BOOK INC                                 100           NaN
# 3463   WORLD BOOK INC                                 280           NaN
# 3464   WORLD WIDE TECHNOLOGY INC                      400           NaN
# 3465   WOWTOYZ                                        280           NaN
# 3466   WRECORP                                        100      16421.00
# 3467   WT COX INFORMATION SERVICES                    100         94.30
# 3468   WT COX INFORMATION SERVICES                    230           NaN
# 3469   WW WILLIAMS                                    100           NaN
# 3470   WW WILLIAMS                                    700      18409.86
# 3471   X1 DISCOVERY INC                               100           NaN
# 3472   XCESSORIES SQUARED SOUTHWEST INC               200           NaN
# 3473   XCESSORIES SQUARED SOUTHWEST INC               458           NaN
# 3474   XIOMARA M TENREIRO                             100           NaN
# 3475   XIOMARA STABACK SMITH                          100           NaN
# 3476   XYLEM WATER SOLUTIONS USA INC                  603           NaN
# 3477   YAHOO                                          100        100.00
# 3478   YESCO LLC                                      100           NaN
# 3479   YESENIA FIGUEROA DIAZ                          230           NaN
# 3480   YLS ENTERPRISES LLC                            600           NaN
# 3481   YLS ENTERPRISES LLC                            603           NaN
# 3482   YOLANDA ANITA FACIO                            230           NaN
# 3483   YVONNE MARIE HERTEL                            100           NaN
# 3484   ZAP MANUFACTURING INC                          200       1137.17
# 3485   ZAYO GROUP LLC                                 100           NaN
# 3486   ZENON ENVIRONMENTAL CORP                       600           NaN
# 3487   ZENON ENVIRONMENTAL CORP                       602     258517.14
# 3488   ZETX                                           100           NaN
# 3489   ZIONS FIRST NATIONAL BANK                      300           NaN
# 3490   ZUMAR INDUSTRIES INC                           200           NaN
# 3491   ZYLAB NORTH AMERICA LLC                        100           NaN
#
#                                                                              \
#
# Month        2         3          4         5        6         7          8
# 0          NaN       NaN        NaN     96.16    96.16       NaN      96.16
# 1          NaN       NaN        NaN    556.03      NaN       NaN        NaN
# 2      7500.00       NaN        NaN       NaN      NaN       NaN        NaN
# 3          NaN   2850.53        NaN       NaN      NaN       NaN    1559.98
# 4          NaN       NaN        NaN       NaN  3894.32       NaN     939.54
# 5          NaN       NaN        NaN       NaN      NaN       NaN        NaN
# 6          NaN   1489.69    1316.95       NaN      NaN    965.84        NaN
# 7          NaN       NaN        NaN       NaN      NaN       NaN        NaN
# 8          NaN       NaN        NaN       NaN      NaN   4431.55        NaN
# 9          NaN       NaN     518.16       NaN      NaN       NaN        NaN
# 10         NaN       NaN        NaN       NaN   242.89       NaN        NaN
# 11         NaN       NaN        NaN       NaN      NaN       NaN        NaN
# 12     2859.50  10937.54    2059.48   1206.58  4418.76   1450.62    2415.88
# 13         NaN       NaN        NaN  15416.87      NaN       NaN        NaN
# 14         NaN       NaN        NaN   9590.25      NaN       NaN        NaN
# 15         NaN       NaN    1140.00    265.00   770.00    840.00        NaN
# 16         NaN       NaN        NaN       NaN      NaN       NaN        NaN
# 17      840.00    560.00    1750.00   1260.00  1400.00    420.00     195.00
# 18       39.96    289.22     796.21       NaN  2528.60   2931.12        NaN
# 19         NaN       NaN        NaN       NaN      NaN       NaN    1021.38
# 20         NaN       NaN        NaN       NaN      NaN       NaN    1476.96
# 21         NaN       NaN        NaN       NaN      NaN    248.73        NaN
# 22         NaN       NaN        NaN       NaN      NaN       NaN        NaN
# 23      704.01       NaN     551.50       NaN      NaN    313.56        NaN
# 24     2728.75       NaN    2210.57   4821.60  2797.18   2565.55    2902.14
# 25         NaN       NaN     270.00       NaN   270.00       NaN        NaN
# 26         NaN       NaN        NaN       NaN      NaN       NaN     118.73
# 27         NaN    149.28        NaN    149.17   288.39       NaN        NaN
# 28         NaN       NaN     157.79    780.00      NaN       NaN        NaN
# 29         NaN       NaN        NaN       NaN      NaN       NaN        NaN
# ...        ...       ...        ...       ...      ...       ...        ...
# 3462       NaN    994.00        NaN       NaN      NaN       NaN        NaN
# 3463       NaN   5000.00        NaN       NaN      NaN       NaN        NaN
# 3464       NaN       NaN  395023.98  45078.19      NaN  88943.66        NaN
# 3465   1264.81       NaN    1740.41       NaN      NaN       NaN        NaN
# 3466       NaN       NaN    2220.00       NaN  3500.00       NaN        NaN
# 3467       NaN  26614.56     441.60       NaN     9.18     20.03        NaN
# 3468       NaN       NaN     883.20       NaN      NaN       NaN        NaN
# 3469       NaN       NaN        NaN   1864.60      NaN   3045.96        NaN
# 3470   5630.62   2657.97    2115.21   4934.84  1596.51   7997.99        NaN
# 3471       NaN       NaN        NaN       NaN      NaN   1995.00        NaN
# 3472       NaN       NaN    3002.88       NaN      NaN       NaN    2281.86
# 3473       NaN       NaN        NaN       NaN      NaN       NaN        NaN
# 3474       NaN    300.00        NaN       NaN      NaN       NaN     750.00
# 3475       NaN       NaN        NaN       NaN   618.75       NaN        NaN
# 3476    235.17    573.25        NaN       NaN      NaN       NaN        NaN
# 3477       NaN       NaN        NaN       NaN      NaN       NaN        NaN
# 3478       NaN       NaN        NaN       NaN      NaN   2263.00        NaN
# 3479       NaN       NaN        NaN       NaN      NaN       NaN      14.00
# 3480       NaN   5983.55    7605.33       NaN      NaN       NaN    2467.27
# 3481       NaN    767.49    8233.40       NaN      NaN       NaN        NaN
# 3482       NaN       NaN        NaN       NaN      NaN       NaN        NaN
# 3483    105.75     33.56        NaN       NaN      NaN       NaN        NaN
# 3484       NaN       NaN    1719.03       NaN      NaN   2966.55        NaN
# 3485       NaN       NaN        NaN       NaN      NaN   1240.00        NaN
# 3486       NaN       NaN        NaN       NaN      NaN       NaN        NaN
# 3487       NaN       NaN        NaN       NaN      NaN       NaN  258517.14
# 3488       NaN       NaN    3200.00       NaN      NaN       NaN        NaN
# 3489       NaN       NaN        NaN       NaN      NaN       NaN        NaN
# 3490       NaN       NaN        NaN       NaN      NaN       NaN    5753.74
# 3491       NaN       NaN        NaN       NaN      NaN       NaN        NaN
#
#
#
# Month         9        10        11        12
# 0        852.35     96.16       NaN       NaN
# 1           NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN
# 3           NaN  10909.73       NaN       NaN
# 4           NaN       NaN    613.74       NaN
# 5           NaN       NaN    593.61       NaN
# 6           NaN       NaN       NaN       NaN
# 7       3500.00       NaN    600.00       NaN
# 8           NaN       NaN       NaN       NaN
# 9           NaN       NaN   1623.57       NaN
# 10          NaN       NaN       NaN       NaN
# 11       360.00       NaN       NaN       NaN
# 12      1450.62   1450.62   3294.73   1938.74
# 13          NaN       NaN       NaN       NaN
# 14          NaN   9590.25       NaN       NaN
# 15      1875.00       NaN       NaN   1170.00
# 16          NaN       NaN    420.00       NaN
# 17      1050.00    315.00   1125.00    140.00
# 18          NaN    288.08       NaN       NaN
# 19          NaN       NaN       NaN       NaN
# 20          NaN       NaN       NaN       NaN
# 21      2125.48    620.41     64.18   1594.45
# 22          NaN       NaN       NaN    847.03
# 23          NaN       NaN       NaN       NaN
# 24          NaN   3050.80   2799.50   5435.44
# 25          NaN       NaN       NaN       NaN
# 26          NaN       NaN       NaN       NaN
# 27          NaN    147.70       NaN       NaN
# 28          NaN       NaN    275.70       NaN
# 29       350.00       NaN       NaN       NaN
# ...         ...       ...       ...       ...
# 3462        NaN       NaN       NaN       NaN
# 3463        NaN       NaN       NaN       NaN
# 3464        NaN       NaN       NaN       NaN
# 3465        NaN   1506.83       NaN   1013.30
# 3466        NaN       NaN       NaN       NaN
# 3467        NaN       NaN       NaN       NaN
# 3468        NaN       NaN       NaN       NaN
# 3469        NaN       NaN       NaN       NaN
# 3470   16201.09  31435.38   2288.63       NaN
# 3471        NaN       NaN       NaN       NaN
# 3472   22547.71       NaN       NaN       NaN
# 3473        NaN   5574.91       NaN       NaN
# 3474        NaN       NaN       NaN       NaN
# 3475        NaN       NaN       NaN       NaN
# 3476    4156.08       NaN       NaN       NaN
# 3477      80.00       NaN       NaN       NaN
# 3478        NaN       NaN       NaN       NaN
# 3479        NaN       NaN       NaN       NaN
# 3480    4284.29   1155.08   7693.66  14112.40
# 3481        NaN       NaN   4098.96       NaN
# 3482     750.00    750.00    750.00       NaN
# 3483        NaN       NaN       NaN       NaN
# 3484        NaN   1281.84       NaN       NaN
# 3485        NaN       NaN       NaN       NaN
# 3486        NaN  20403.00       NaN       NaN
# 3487        NaN       NaN       NaN       NaN
# 3488        NaN       NaN       NaN       NaN
# 3489        NaN       NaN       NaN    650.00
# 3490        NaN       NaN       NaN       NaN
# 3491        NaN       NaN  46000.00       NaN
#
# [3492 rows x 14 columns]
