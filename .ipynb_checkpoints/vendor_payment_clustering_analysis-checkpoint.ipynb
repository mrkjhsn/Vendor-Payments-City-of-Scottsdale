# %% [markdown]
# ## Clustering Analysis
#
# #### Using the City of Scottsdale Vendor Payments [dataset](http://data.scottsdaleaz.gov/dataset/vendor-payments) and performing time series analysis, many vendors receive payments from the city at regular intervals throughout the year(monthly, weekly, daily).  In contrast to these vendors, I'm interested in identifying vendors who receive payments within compressed time spans during the year?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker
import seaborn as sns

vendor_payments = pd.read_csv('data/Scottsdale/ct_VendorPayments.csv')
vendor_payments['PaymentDate'] = pd.to_datetime(vendor_payments['PaymentDate'])
vendor_payments['Month'] = vendor_payments['PaymentDate'].dt.month
vendor_payments['Day_of_Year'] = vendor_payments['PaymentDate'].dt.dayofyear

# convert datetime to a number to be able to find mean payment for each vendor
vendor_payments['Payment_Date_Numeric'] = pd.to_datetime(vendor_payments['PaymentDate']).values.astype(np.int64)

# %%
vendor_payments.shape
# Out:
# (23612, 14)

# %%
vendor_payments.head()
# Out:
#   PaymentDate                                     VendorName  PaymentAmount  \
# 0  2017-08-14  A TO Z EQUIPMENT RENTAL & SALES                      1021.38
# 1  2017-08-22  A TO Z EQUIPMENT RENTAL & SALES                      1476.96
# 2  2017-09-29  A TO Z EQUIPMENT RENTAL & SALES                      2125.48
# 3  2017-10-02  A TO Z EQUIPMENT RENTAL & SALES                       288.08
# 4  2017-10-11  A TO Z EQUIPMENT RENTAL & SALES                       579.66
#
#    Fund FundDescription Center                           CenterName  Account  \
# 0   200  TRANSPORTATION  20860  TRAFFIC SIGNALS                        53790
# 1   230          GRANTS  36209  SRP-MIC FY16/17 MUNOZ-VILLAFAN         53090
# 2   600           WATER  29201  WATER DISTRIBUTION                     53720
# 3   100         GENERAL  20907  CONSTRUCTION SERVICES                  52360
# 4   600           WATER  29201  WATER DISTRIBUTION                     53794
#
#                            AccountName  FiscalYear  AccountingPeriod  Month  \
# 0  MAT TO MAINT & REPAIR MACH, EQUIP          2018                 2      8
# 1  OTHER OPERATING SUPPLIES                   2018                 2      8
# 2  SMALL TOOLS & EQUIPMENT                    2018                 3      9
# 3  MAINT - MACHINERY, EQUIP & AUTOS           2018                 4     10
# 4  MAT TO MAINT AND REPAIR MECH SYS           2018                 4     10
#
#    Day_of_Year  Payment_Date_Numeric     Payment_Date_Avg  Payment_Count  \
# 0          226   1502668800000000000  1516583314285714176             21
# 1          234   1503360000000000000  1516583314285714176             21
# 2          272   1506643200000000000  1516583314285714176             21
# 3          275   1506902400000000000  1516583314285714176             21
# 4          284   1507680000000000000  1516583314285714176             21
#
#             Date_Dif
# 0  13914514285714176
# 1  13223314285714176
# 2   9940114285714176
# 3   9680914285714176
# 4   8903314285714176

# %% [markdown]
# ### Preprocess the data

# %%
vendor_payments.dtypes
# Out:
# PaymentDate             datetime64[ns]
# VendorName                      object
# PaymentAmount                  float64
# Fund                             int64
# FundDescription                 object
# Center                          object
# CenterName                      object
# Account                          int64
# AccountName                     object
# FiscalYear                       int64
# AccountingPeriod                 int64
# Month                            int64
# Day_of_Year                      int64
# Payment_Date_Numeric             int64
# dtype: object

# %%
# find the average payment date for each vendor
avg_payment_date_by_vendor = vendor_payments.groupby('VendorName')['Payment_Date_Numeric'] \
    .mean().to_frame().rename(columns={'Payment_Date_Numeric': 'Payment_Date_Avg'})

avg_payment_date_by_vendor.head()
# Out:
#                                                   Payment_Date_Avg
# VendorName
# 1 800 RADIATOR                                 1510822800000000000
# 1800 RADIATOR                                  1525867200000000000
# 232 RANCH LLC                                  1518739200000000000
# 3M                                             1511928000000000000
# 4IMPRINT INC                                   1518614400000000000

# %%
vendor_payments.shape
# Out:
# (23612, 14)

# %%
# find the count of payments for each vendor
count_vendor_payments_by_vendor = vendor_payments.groupby('VendorName')['Payment_Date_Numeric'] \
.count().to_frame().rename(columns={'Payment_Date_Numeric': 'Payment_Count'})

count_vendor_payments_by_vendor.head()
# head()
# Out:
#                                                Payment_Count
# VendorName
# 1 800 RADIATOR                                             8
# 1800 RADIATOR                                              2
# 232 RANCH LLC                                              1
# 3M                                                         6
# 4IMPRINT INC                                               9

# %%
# merge vendor date averages with vendor payments
vendor_payments = pd.merge(vendor_payments, avg_payment_date_by_vendor, on='VendorName')
vendor_payments.head()
# Out:
#   PaymentDate                                     VendorName  PaymentAmount  \
# 0  2017-08-14  A TO Z EQUIPMENT RENTAL & SALES                      1021.38
# 1  2017-08-22  A TO Z EQUIPMENT RENTAL & SALES                      1476.96
# 2  2017-09-29  A TO Z EQUIPMENT RENTAL & SALES                      2125.48
# 3  2017-10-02  A TO Z EQUIPMENT RENTAL & SALES                       288.08
# 4  2017-10-11  A TO Z EQUIPMENT RENTAL & SALES                       579.66
#
#    Fund FundDescription Center                           CenterName  Account  \
# 0   200  TRANSPORTATION  20860  TRAFFIC SIGNALS                        53790
# 1   230          GRANTS  36209  SRP-MIC FY16/17 MUNOZ-VILLAFAN         53090
# 2   600           WATER  29201  WATER DISTRIBUTION                     53720
# 3   100         GENERAL  20907  CONSTRUCTION SERVICES                  52360
# 4   600           WATER  29201  WATER DISTRIBUTION                     53794
#
#                            AccountName  FiscalYear  AccountingPeriod  Month  \
# 0  MAT TO MAINT & REPAIR MACH, EQUIP          2018                 2      8
# 1  OTHER OPERATING SUPPLIES                   2018                 2      8
# 2  SMALL TOOLS & EQUIPMENT                    2018                 3      9
# 3  MAINT - MACHINERY, EQUIP & AUTOS           2018                 4     10
# 4  MAT TO MAINT AND REPAIR MECH SYS           2018                 4     10
#
#    Day_of_Year  Payment_Date_Numeric     Payment_Date_Avg
# 0          226   1502668800000000000  1516583314285714176
# 1          234   1503360000000000000  1516583314285714176
# 2          272   1506643200000000000  1516583314285714176
# 3          275   1506902400000000000  1516583314285714176
# 4          284   1507680000000000000  1516583314285714176

# %%
# merge vendor payment counts with vendor payments
vendor_payments = pd.merge(vendor_payments, count_vendor_payments_by_vendor, on='VendorName')
vendor_payments.head()
# Out:
#   PaymentDate                                     VendorName  PaymentAmount  \
# 0  2017-08-14  A TO Z EQUIPMENT RENTAL & SALES                      1021.38
# 1  2017-08-22  A TO Z EQUIPMENT RENTAL & SALES                      1476.96
# 2  2017-09-29  A TO Z EQUIPMENT RENTAL & SALES                      2125.48
# 3  2017-10-02  A TO Z EQUIPMENT RENTAL & SALES                       288.08
# 4  2017-10-11  A TO Z EQUIPMENT RENTAL & SALES                       579.66
#
#    Fund FundDescription Center                           CenterName  Account  \
# 0   200  TRANSPORTATION  20860  TRAFFIC SIGNALS                        53790
# 1   230          GRANTS  36209  SRP-MIC FY16/17 MUNOZ-VILLAFAN         53090
# 2   600           WATER  29201  WATER DISTRIBUTION                     53720
# 3   100         GENERAL  20907  CONSTRUCTION SERVICES                  52360
# 4   600           WATER  29201  WATER DISTRIBUTION                     53794
#
#                            AccountName  FiscalYear  AccountingPeriod  Month  \
# 0  MAT TO MAINT & REPAIR MACH, EQUIP          2018                 2      8
# 1  OTHER OPERATING SUPPLIES                   2018                 2      8
# 2  SMALL TOOLS & EQUIPMENT                    2018                 3      9
# 3  MAINT - MACHINERY, EQUIP & AUTOS           2018                 4     10
# 4  MAT TO MAINT AND REPAIR MECH SYS           2018                 4     10
#
#    Day_of_Year  Payment_Date_Numeric     Payment_Date_Avg  Payment_Count
# 0          226   1502668800000000000  1516583314285714176             21
# 1          234   1503360000000000000  1516583314285714176             21
# 2          272   1506643200000000000  1516583314285714176             21
# 3          275   1506902400000000000  1516583314285714176             21
# 4          284   1507680000000000000  1516583314285714176             21

# %%
# find difference from mean date for each vendor payment
vendor_payments['Date_Dif'] = abs(vendor_payments['Payment_Date_Avg'] - vendor_payments['Payment_Date_Numeric'])

# %%
vendor_payments.sort_values(by='Date_Dif', ascending=False).head()
# Out:
#       PaymentDate                                     VendorName  \
# 8068   2017-08-18  BIBLIOTHECA LLC
# 18795  2017-09-25  RITOCH-POWELL & ASSOCIATES
# 11069  2018-07-13  COMPRESSED AIR POWER INC
# 9866   2018-08-07  UCT LLC
# 16521  2017-09-06  AT&T MOBILITY
#
#        PaymentAmount  Fund                    FundDescription Center  \
# 8068        72578.00   100                            GENERAL  25603
# 18795         658.38   410  CIP TRANSPORTATION PRIVILEGE TAX   TB57A
# 11069         693.28   100                            GENERAL  20905
# 9866          565.81   603                  WATER RECLAMATION  29470
# 16521       33936.25   100                            GENERAL  27501
#
#                                 CenterName  Account  \
# 8068   LIBRARY SYSTEMS                        52340
# 18795  HAYDEN/THOMAS SAFETY IMP               56047
# 11069  HVAC MAINTENANCE                       52360
# 9866   WATER RECLAMATION LABORATORY           53040
# 16521  NETWORK OPERATIONS                     52350
#
#                                AccountName  FiscalYear  AccountingPeriod  \
# 8068   MAINTENANCE, OFF EQUIP & FURNITURE         2018                 2
# 18795  DSGN - ENGINEERING SERVICES                2018                 3
# 11069  MAINT - MACHINERY, EQUIP & AUTOS           2019                 1
# 9866   CHEMICALS & LABORATORY SUPPLIES            2019                 2
# 16521  SOFTWARE MAINT & LICENSING                 2018                 3
#
#        Month  Day_of_Year  Payment_Date_Numeric     Payment_Date_Avg  \
# 8068       8          230   1503014400000000000  1526100480000000000
# 18795      9          268   1506297600000000000  1527573600000000000
# 11069      7          194   1531440000000000000  1510168320000000000
# 9866       8          219   1533600000000000000  1513244160000000000
# 16521      9          249   1504656000000000000  1524852000000000000
#
#        Payment_Count           Date_Dif
# 8068               5  23086080000000000
# 18795              8  21276000000000000
# 11069              5  21271680000000000
# 9866               5  20355840000000000
# 16521              4  20196000000000000

# %%
# reduce vendor payments to only vendors with more than 10 payments during the year
vendor_payments = vendor_payments[vendor_payments['Payment_Count'] >= 10]

vendor_payments.head()
# Out:
#   PaymentDate                                     VendorName  PaymentAmount  \
# 0  2017-08-14  A TO Z EQUIPMENT RENTAL & SALES                      1021.38
# 1  2017-08-22  A TO Z EQUIPMENT RENTAL & SALES                      1476.96
# 2  2017-09-29  A TO Z EQUIPMENT RENTAL & SALES                      2125.48
# 3  2017-10-02  A TO Z EQUIPMENT RENTAL & SALES                       288.08
# 4  2017-10-11  A TO Z EQUIPMENT RENTAL & SALES                       579.66
#
#    Fund FundDescription Center                           CenterName  Account  \
# 0   200  TRANSPORTATION  20860  TRAFFIC SIGNALS                        53790
# 1   230          GRANTS  36209  SRP-MIC FY16/17 MUNOZ-VILLAFAN         53090
# 2   600           WATER  29201  WATER DISTRIBUTION                     53720
# 3   100         GENERAL  20907  CONSTRUCTION SERVICES                  52360
# 4   600           WATER  29201  WATER DISTRIBUTION                     53794
#
#                            AccountName  FiscalYear  AccountingPeriod  Month  \
# 0  MAT TO MAINT & REPAIR MACH, EQUIP          2018                 2      8
# 1  OTHER OPERATING SUPPLIES                   2018                 2      8
# 2  SMALL TOOLS & EQUIPMENT                    2018                 3      9
# 3  MAINT - MACHINERY, EQUIP & AUTOS           2018                 4     10
# 4  MAT TO MAINT AND REPAIR MECH SYS           2018                 4     10
#
#    Day_of_Year  Payment_Date_Numeric     Payment_Date_Avg  Payment_Count  \
# 0          226   1502668800000000000  1516583314285714176             21
# 1          234   1503360000000000000  1516583314285714176             21
# 2          272   1506643200000000000  1516583314285714176             21
# 3          275   1506902400000000000  1516583314285714176             21
# 4          284   1507680000000000000  1516583314285714176             21
#
#             Date_Dif
# 0  13914514285714176
# 1  13223314285714176
# 2   9940114285714176
# 3   9680914285714176
# 4   8903314285714176

# %%
# divide sum of vendor date differences by transaction counts for each vendor
dif_dates_aggregated = vendor_payments.groupby('VendorName')['Date_Dif'].sum().to_frame()

vendor_payments_count = vendor_payments.groupby('VendorName')['Date_Dif'].count().to_frame()
    

# merge vendor payment counts with vendor payments
vendors_clustered = pd.merge(dif_dates_aggregated, vendor_payments_count, left_index=True, right_index=True)
vendors_clustered['cluster_score'] = vendors_clustered['Date_Dif_x']/vendors_clustered['Date_Dif_y']

top_clustered_vendors = vendors_clustered.sort_values(by='cluster_score', ascending=True)
top_clustered_vendors.head()
# Out:
#                                                       Date_Dif_x  Date_Dif_y  \
# VendorName
# AZ WATER ASSOCIATION                                           0          14
# AMERICAN PUBLIC WORKS ASSOC                                    0          10
# LOFTIN EQUIPMENT CO                             2880000000000000          12
# LN CURTIS & SONS                               13962240000000000          10
# SOMERSET LANDSCAPE                             48614400000001280          33
#
#                                                cluster_score
# VendorName
# AZ WATER ASSOCIATION                            0.000000e+00
# AMERICAN PUBLIC WORKS ASSOC                     0.000000e+00
# LOFTIN EQUIPMENT CO                             2.400000e+14
# LN CURTIS & SONS                                1.396224e+15
# SOMERSET LANDSCAPE                              1.473164e+15

# %%
# subset data based on top 10 vendors from cluster analysis

top_clustered_vendors_data = vendor_payments[vendor_payments['VendorName'].isin(top_clustered_vendors.head(8).index)]
# top_clustered_vendors_data.loc[:,'PaymentDate'].head()
top_clustered_vendors_data.head()

# set VendorName to index
top_clustered_vendors_data.set_index('VendorName', inplace=True)
top_clustered_vendors_data.index = top_clustered_vendors_data.index.str.strip()

# s.str.strip()

# top_clustered_vendors_data.index.map(str)



# astype(str)


# df.index = df.index.map(str)

# df['id'].astype(str)
# top_clustered_vendors_data.head()

# %%
top_clustered_vendors_data.index
# Out:
# Index(['SOMERSET LANDSCAPE', 'SOMERSET LANDSCAPE', 'SOMERSET LANDSCAPE',
#        'SOMERSET LANDSCAPE', 'SOMERSET LANDSCAPE', 'SOMERSET LANDSCAPE',
#        'SOMERSET LANDSCAPE', 'SOMERSET LANDSCAPE', 'SOMERSET LANDSCAPE',
#        'SOMERSET LANDSCAPE',
#        ...
#        'LOFTIN EQUIPMENT CO', 'LOFTIN EQUIPMENT CO', 'LOFTIN EQUIPMENT CO',
#        'LOFTIN EQUIPMENT CO', 'LOFTIN EQUIPMENT CO', 'LOFTIN EQUIPMENT CO',
#        'LOFTIN EQUIPMENT CO', 'LOFTIN EQUIPMENT CO', 'LOFTIN EQUIPMENT CO',
#        'LOFTIN EQUIPMENT CO'],
#       dtype='object', name='VendorName', length=133)

# %%
fig = plt.figure(figsize=(15, 5))
ax = sns.color_palette("dark")

ax = sns.scatterplot(x=top_clustered_vendors_data.loc[:,'Day_of_Year'], 
                y=top_clustered_vendors_data.loc[:,'PaymentAmount'], 
                hue=top_clustered_vendors_data.index,
                    s=100)

# plt.title("xxx")
plt.xlabel("Day of the Year", fontsize=15)
plt.ylabel("Payment Amount($)", fontsize=15)
plt.legend(fontsize=15)

# sns.set_context("notebook", font_scale=1)

plt.ylim(0,5000)
ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(25))

plt.legend(frameon=False)
# plt.savefig("visualizations/top 8 clustered vendors.png")

# %%
top_clustered_vendors_data.loc['SOMERSET LANDSCAPE'].head()

# top_clustered_vendors_data.head()
# Out:
#                    PaymentDate  PaymentAmount  Fund  \
# VendorName
# SOMERSET LANDSCAPE  2017-08-14         458.38   100
# SOMERSET LANDSCAPE  2017-08-18        4107.60   458
# SOMERSET LANDSCAPE  2017-08-21        4851.12   100
# SOMERSET LANDSCAPE  2017-08-21         501.84   100
# SOMERSET LANDSCAPE  2017-08-21        2675.00   100
#
#                                      FundDescription Center  \
# VendorName
# SOMERSET LANDSCAPE                           GENERAL  25412
# SOMERSET LANDSCAPE  PRESERVE TAX '04-LAND & IMPRVMTS  PB52A
# SOMERSET LANDSCAPE                           GENERAL  25401
# SOMERSET LANDSCAPE                           GENERAL  25404
# SOMERSET LANDSCAPE                           GENERAL  25408
#
#                                              CenterName  Account  \
# VendorName
# SOMERSET LANDSCAPE  MEDIANS & RIGHT-OF-WAY MAINTENANCE     52323
# SOMERSET LANDSCAPE  RESTORE,HABITAT,FIRE/SAFTY IMP         56081
# SOMERSET LANDSCAPE  CIVIC CENTER COMPLEX                   52323
# SOMERSET LANDSCAPE  PROFESSIONAL BASEBALL                  52323
# SOMERSET LANDSCAPE  STORM DAMAGE REPAIR AND MAINTENANCE    52323
#
#                                             AccountName  FiscalYear  \
# VendorName
# SOMERSET LANDSCAPE  LANDSCAPING                                2018
# SOMERSET LANDSCAPE  CONT - LAND IMPROVEMENTS                   2018
# SOMERSET LANDSCAPE  LANDSCAPING                                2018
# SOMERSET LANDSCAPE  LANDSCAPING                                2018
# SOMERSET LANDSCAPE  LANDSCAPING                                2018
#
#                     AccountingPeriod  Month  Day_of_Year  \
# VendorName
# SOMERSET LANDSCAPE                 2      8          226
# SOMERSET LANDSCAPE                 2      8          230
# SOMERSET LANDSCAPE                 2      8          233
# SOMERSET LANDSCAPE                 2      8          233
# SOMERSET LANDSCAPE                 2      8          233
#
#                     Payment_Date_Numeric     Payment_Date_Avg  Payment_Count  \
# VendorName
# SOMERSET LANDSCAPE   1502668800000000000  1505601163636363520             33
# SOMERSET LANDSCAPE   1503014400000000000  1505601163636363520             33
# SOMERSET LANDSCAPE   1503273600000000000  1505601163636363520             33
# SOMERSET LANDSCAPE   1503273600000000000  1505601163636363520             33
# SOMERSET LANDSCAPE   1503273600000000000  1505601163636363520             33
#
#                             Date_Dif
# VendorName
# SOMERSET LANDSCAPE  2932363636363520
# SOMERSET LANDSCAPE  2586763636363520
# SOMERSET LANDSCAPE  2327563636363520
# SOMERSET LANDSCAPE  2327563636363520
# SOMERSET LANDSCAPE  2327563636363520

# %%
plt.figure(figsize=(15, 1))

sns.scatterplot(x=top_clustered_vendors_data.loc['SOMERSET LANDSCAPE','Day_of_Year'], 
                y=top_clustered_vendors_data.loc['SOMERSET LANDSCAPE','PaymentAmount'], s=100)


# sns.set_context("notebook", font_scale=1)

# plt.ylim(0,5000)

# %%
plt.figure(figsize=(15, 8))
plt.xlim(0, 360)  




plt.subplot(3, 1, 1)
# plt.plot(x1, y1, 'o-')
##########
sns.scatterplot(x=top_clustered_vendors_data.loc['SOMERSET LANDSCAPE','Day_of_Year'], 
                y=top_clustered_vendors_data.loc['SOMERSET LANDSCAPE','PaymentAmount'], s=100, color='red')
plt.xlim(0, 360)  

##############

plt.title('A tale of 2 subplots')
# plt.ylabel('Damped oscillation')
##############

##############
plt.subplot(3, 1, 2)
# plt.plot(x2, y2, '.-')

# plt.figure(figsize=(15, 1))

sns.scatterplot(x=top_clustered_vendors_data.loc['LOFTIN EQUIPMENT CO','Day_of_Year'], 
                y=top_clustered_vendors_data.loc['LOFTIN EQUIPMENT CO','PaymentAmount'], s=100)
plt.xlim(0, 360)  


plt.xlabel('time (s)')
# plt.ylabel('Undamped')

plt.subplot(3, 1, 3)


# plt.show()
