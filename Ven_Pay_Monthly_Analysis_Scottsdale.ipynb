# %% [markdown]
# ### Opportunity to explore vendor payments(City of Scottsdale) and experiment with pandas styling features.  Following along from example by [Chris Moffitt](https://pbpython.com/styling-pandas.html)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker
import seaborn as sns
import datetime

vendor_payments = pd.read_csv("data/Scottsdale/ct_VendorPayments.csv")

vendor_payments['PaymentDate'] = pd.to_datetime(vendor_payments['PaymentDate'])
vendor_payments['Month'] = vendor_payments['PaymentDate'].dt.month
vendor_payments['Day_of_Year'] = vendor_payments['PaymentDate'].dt.dayofyear

# %%
# date range of data
print(vendor_payments['PaymentDate'].min())
print(vendor_payments['PaymentDate'].max())
# Out:
# 2017-08-14 00:00:00
# 2018-08-10 00:00:00

# %%
vendor_payments.head()
# Out:
#   PaymentDate                                     VendorName  PaymentAmount  \
# 0  2017-08-14  A TO Z EQUIPMENT RENTAL & SALES                      1021.38
# 1  2017-08-14  AIMS PVIC                                             380.00
# 2  2017-08-14  AIMS PVIC                                            2125.00
# 3  2017-08-14  AIMS PVIC                                           15658.03
# 4  2017-08-14  ALL CITY TOWING                                       583.00
#
#    Fund    FundDescription Center                           CenterName  \
# 0   200     TRANSPORTATION  20860  TRAFFIC SIGNALS
# 1   100            GENERAL  25411  IRRIGATION REPAIR
# 2   200     TRANSPORTATION  20810  GRADING AND DRAINAGE
# 3   603  WATER RECLAMATION  29321  SEWER SYSTEM
# 4   700   FLEET MANAGEMENT  20706  FLEET MANAGEMENT OPERATIONS
#
#    Account                          AccountName  FiscalYear  AccountingPeriod  \
# 0    53790  MAT TO MAINT & REPAIR MACH, EQUIP          2018                 2
# 1    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
# 2    52390  MISC MAINTENANCE AND REPAIR                2018                 2
# 3    52190  OTHER PROFESSIONAL SERVICES                2018                 2
# 4    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
#
#    Month  Day_of_Year
# 0      8          226
# 1      8          226
# 2      8          226
# 3      8          226
# 4      8          226

# %%
# group by month and subtotal data for each month
monthly_payments = vendor_payments.groupby([pd.Grouper(key='PaymentDate', freq='M')]) \
    ['PaymentAmount'].agg('sum') \
    .reset_index()

# compute percent of total for each month
monthly_payments['percent_total'] = monthly_payments['PaymentAmount'] / monthly_payments['PaymentAmount'].sum()

# format data to be more readable
monthly_payments = monthly_payments.style.format({'PaymentAmount': '${0:,.0f}', 'percent_total': '{:.2%}'}).hide_index()
monthly_payments
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >PaymentDate</th>
#         <th class="col_heading level0 col1" >PaymentAmount</th>
#         <th class="col_heading level0 col2" >percent_total</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row0_col0" class="data row0 col0" >2017-08-31 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row0_col1" class="data row0 col1" >$16,407,638</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row0_col2" class="data row0 col2" >5.65%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row1_col0" class="data row1 col0" >2017-09-30 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row1_col1" class="data row1 col1" >$18,977,599</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row1_col2" class="data row1 col2" >6.53%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row2_col0" class="data row2 col0" >2017-10-31 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row2_col1" class="data row2 col1" >$27,377,901</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row2_col2" class="data row2 col2" >9.42%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row3_col0" class="data row3 col0" >2017-11-30 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row3_col1" class="data row3 col1" >$21,451,298</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row3_col2" class="data row3 col2" >7.38%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row4_col0" class="data row4 col0" >2017-12-31 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row4_col1" class="data row4 col1" >$25,749,321</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row4_col2" class="data row4 col2" >8.86%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row5_col0" class="data row5 col0" >2018-01-31 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row5_col1" class="data row5 col1" >$24,807,941</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row5_col2" class="data row5 col2" >8.54%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row6_col0" class="data row6 col0" >2018-02-28 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row6_col1" class="data row6 col1" >$22,644,036</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row6_col2" class="data row6 col2" >7.79%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row7_col0" class="data row7 col0" >2018-03-31 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row7_col1" class="data row7 col1" >$21,600,046</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row7_col2" class="data row7 col2" >7.43%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row8_col0" class="data row8 col0" >2018-04-30 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row8_col1" class="data row8 col1" >$24,666,970</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row8_col2" class="data row8 col2" >8.49%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row9_col0" class="data row9 col0" >2018-05-31 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row9_col1" class="data row9 col1" >$26,209,036</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row9_col2" class="data row9 col2" >9.02%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row10_col0" class="data row10 col0" >2018-06-30 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row10_col1" class="data row10 col1" >$26,232,086</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row10_col2" class="data row10 col2" >9.03%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row11_col0" class="data row11 col0" >2018-07-31 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row11_col1" class="data row11 col1" >$28,584,890</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row11_col2" class="data row11 col2" >9.83%</td>
#     </tr>    <tr>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row12_col0" class="data row12 col0" >2018-08-31 00:00:00</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row12_col1" class="data row12 col1" >$5,948,562</td>
#         <td id="T_d16a8928_97a0_11e9_a6bc_9cb6d0ea6ad2row12_col2" class="data row12 col2" >2.05%</td>
#     </tr></tbody>
# </table>

# %%
monthly_payments \
    .bar(color='orange',subset=['PaymentAmount'], align='zero') \
    .bar(color='lightblue', subset=['percent_total'], align='zero') \
    .set_caption('Monthly Vendor Payments')
# Out:
# <style  type="text/css" >
#     #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 78.7%, transparent 78.7%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 78.7%, transparent 78.7%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 83.2%, transparent 83.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 83.2%, transparent 83.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 83.2%, transparent 83.2%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 83.2%, transparent 83.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 83.2%, transparent 83.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 83.2%, transparent 83.2%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 97.9%, transparent 97.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 97.9%, transparent 97.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 97.9%, transparent 97.9%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 97.9%, transparent 97.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 97.9%, transparent 97.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 97.9%, transparent 97.9%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 87.5%, transparent 87.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 87.5%, transparent 87.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 87.5%, transparent 87.5%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 87.5%, transparent 87.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 87.5%, transparent 87.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 87.5%, transparent 87.5%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 95.0%, transparent 95.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 95.0%, transparent 95.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 95.0%, transparent 95.0%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 95.0%, transparent 95.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 95.0%, transparent 95.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 95.0%, transparent 95.0%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 93.4%, transparent 93.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 93.4%, transparent 93.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 93.4%, transparent 93.4%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 93.4%, transparent 93.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 93.4%, transparent 93.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, lightblue 50%, lightblue 93.4%, transparent 93.4%);
#         }    #T_f1a9ce5c_97a0_11e9_91b0_9cb6d0ea6ad2row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 89.6%, transparent 89.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 89.6%, transparent 89.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, orange 50%, orange 89.6%, transparent 89.6%);
#         }    #T_f1a9ce5

# %% [markdown]
# #### This is an easy way to glance at the data and get a sense for quantities.  However, I find myself usually sorting to get the largest/smallest values at the top.

# %%
# group by month and subtotal data for each month
fund_payments = vendor_payments.groupby('Fund') \
    ['PaymentAmount'].sum() \
    .reset_index()

# compute percent of total for each fund
fund_payments['percent_total'] = fund_payments['PaymentAmount'] / fund_payments['PaymentAmount'].sum()

# format data to be more readable
fund_payments = fund_payments \
    .style.format({'PaymentAmount': '${0:,.0f}', 'percent_total': '{:.2%}'}) \
    .hide_index() \
    .bar(color='skyblue', subset=['PaymentAmount'])

fund_payments
# Out:
# <style  type="text/css" >
#     #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 100.0%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 33.4%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 1.6%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.8%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.4%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 4.5%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.0%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 7.4%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 31.8%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.3%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 25.8%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 1.1%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 28.4%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.0%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 3.4%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 2.1%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 1.7%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row19_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.0%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.5%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.0%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.1%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 20.1%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.6%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 3.6%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 8.5%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 10.0%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 4.8%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 75.3%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row33_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.4%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row34_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 35.7%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row35_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 23.4%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row36_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 3.9%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row37_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 29.7%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row38_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row39_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 1.9%, transparent 0%);
#         }    #T_f1b42662_97a0_11e9_920d_9cb6d0ea6ad2row40_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,skyblue 0.2%, transparent 0%);
#         }    #T_f1b4266

# %%
vendor_payments.head()
# Out:
#   PaymentDate                                     VendorName  PaymentAmount  \
# 0  2017-08-14  A TO Z EQUIPMENT RENTAL & SALES                      1021.38
# 1  2017-08-14  AIMS PVIC                                             380.00
# 2  2017-08-14  AIMS PVIC                                            2125.00
# 3  2017-08-14  AIMS PVIC                                           15658.03
# 4  2017-08-14  ALL CITY TOWING                                       583.00
#
#    Fund    FundDescription Center                           CenterName  \
# 0   200     TRANSPORTATION  20860  TRAFFIC SIGNALS
# 1   100            GENERAL  25411  IRRIGATION REPAIR
# 2   200     TRANSPORTATION  20810  GRADING AND DRAINAGE
# 3   603  WATER RECLAMATION  29321  SEWER SYSTEM
# 4   700   FLEET MANAGEMENT  20706  FLEET MANAGEMENT OPERATIONS
#
#    Account                          AccountName  FiscalYear  AccountingPeriod  \
# 0    53790  MAT TO MAINT & REPAIR MACH, EQUIP          2018                 2
# 1    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
# 2    52390  MISC MAINTENANCE AND REPAIR                2018                 2
# 3    52190  OTHER PROFESSIONAL SERVICES                2018                 2
# 4    52360  MAINT - MACHINERY, EQUIP & AUTOS           2018                 2
#
#    Month  Day_of_Year
# 0      8          226
# 1      8          226
# 2      8          226
# 3      8          226
# 4      8          226

# %% [markdown]
# ### For each vendor, what funds are they being paid from? and in which months are they receiving those payments?

# %%
pd.pivot_table(vendor_payments, \
               index=['VendorName', 'Fund'], \
               columns=['Month'], \
               aggfunc=[np.sum], \
               values=['PaymentAmount']) \
               .reset_index() \
               .head()
# Out:
#                                           VendorName Fund           sum  \
#                                                           PaymentAmount
# Month                                                                 1
# 0      1 800 RADIATOR                                 700           NaN
# 1      1800 RADIATOR                                  700           NaN
# 2      232 RANCH LLC                                  100           NaN
# 3      3M                                             200       2444.75
# 4      4IMPRINT INC                                   100           NaN
#
#                                                                             \
#
# Month       2        3   4       5        6   7        8       9        10
# 0         NaN      NaN NaN   96.16    96.16 NaN    96.16  852.35     96.16
# 1         NaN      NaN NaN  556.03      NaN NaN      NaN     NaN       NaN
# 2      7500.0      NaN NaN     NaN      NaN NaN      NaN     NaN       NaN
# 3         NaN  2850.53 NaN     NaN      NaN NaN  1559.98     NaN  10909.73
# 4         NaN      NaN NaN     NaN  3894.32 NaN   939.54     NaN       NaN
#
#
#
# Month      11  12
# 0         NaN NaN
# 1         NaN NaN
# 2         NaN NaN
# 3         NaN NaN
# 4      613.74 NaN
